# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **The Emmy Awards: Nominees and Winners:**
#
# Since the first Emmy ceremony in 1949, the television landscape has evolved dramatically, through black-and-white broadcasts, 1950s color TV, 1960s cable expansion, and today’s dominant streaming platforms1. Throughout all these eras, the Emmy Awards, the annual television honors which recognize excellence across categories such as comedy, acting, writing, and technical achievement, have remained the preeminent awards show for the genre.
# Among the three organizations overseeing the awards is the Television Academy. The Television Academy has more than 26,000 members, each belonging to one of 31 peer groups representing specific fields such as acting, directing, and writing. For nominations, all active members can vote in program categories, and peer groups vote within their categories of expertise. Before voting begins, contenders must be submitted to appear on the ballot in a specific category, and aspiring nominees must submit an episode of their best work. After nominations are announced, voters are expected to watch episode submissions on the TV Academy’s streaming platform before casting final votes, deciding on one winner per category, such as “Most Outstanding” Awards for Drama, Comedy, Directing, and Writing.
# This Emmy nominations dataset reflects the evolution of the television industry by highlighting shifting trends and tastes in television.

# %%
# !git clone https://github.com/frontiertechinstitute/datasets/blob/main/Emmy%20Awards%20and%20Nominees%20Data/emmys_original.csv
# Out:
# Cloning into 'emmys_original.csv'...
# fatal: repository 'https://github.com/frontiertechinstitute/datasets/blob/main/Emmy%20Awards%20and%20Nominees%20Data/emmys_original.csv/' not found

# %%
# !git clone https://github.com/frontiertechinstitute/datasets
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 670, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 670 (delta 90), reused 76 (delta 37), pack-reused 483 (from 2)
# Receiving objects: 100% (670/670), 222.52 MiB | 16.27 MiB/s, done.
# Resolving deltas: 100% (211/211), done.
# Updating files: 100% (210/210), done.

# %%
df = pd.read_csv("datasets/Emmy Awards and Nominees Data/emmys_original.csv")

df.head(10)
# Out:
#                                             category  \
# 0  Outstanding Character Voice-Over Performance -...
# 1  Outstanding Character Voice-Over Performance -...
# 2  Outstanding Character Voice-Over Performance -...
# 3  Outstanding Character Voice-Over Performance -...
# 4  Outstanding Production Design For A Narrative ...
# 5  Outstanding Production Design For A Narrative ...
# 6  Outstanding Production Design For A Narrative ...
# 7  Outstanding Production Design For A Narrative ...
# 8  Outstanding Production Design For A Narrative ...
# 9  Outstanding Production Design For A Narrative ...
#
#                                                 logo  \
# 0  https://www.emmys.com/sites/default/files/styl...
# 1  https://www.emmys.com/sites/default/files/styl...
# 2  https://www.emmys.com/sites/default/files/styl...
# 3  https://www.emmys.com/sites/default/files/styl...
# 4  https://www.emmys.com/sites/default/files/styl...
# 5  https://www.emmys.com/sites/default/files/styl...
# 6  https://www.emmys.com/sites/default/files/styl...
# 7  https://www.emmys.com/sites/default/files/styl...
# 8  https://www.emmys.com/sites/default/files/styl...
# 9  https://www.emmys.com/sites/default/files/styl...
#
#                                 production     type  \
# 0                                      NaN  Nominee
# 1                                      NaN  Nominee
# 2                                      NaN  Nominee
# 3                                      NaN  Nominee
# 4  Elisabeth Williams, Production Designer  Nominee
# 5             Martha Sparrow, Art Director  Nominee
# 6              Larry Spittle, Art Director  Nominee
# 7               Rob Hepburn, Set Decorator  Nominee
# 8        Lester Cohen, Production Designer  Nominee
# 9                Doug Huszti, Art Director  Nominee
#
#                                   title  distributor  \
# 0  black-ish: Election Special (Part 2)          ABC
# 1                            Bridgerton      Netflix
# 2                            Family Guy          FOX
# 3                                Archer  FX Networks
# 4                   The Handmaid's Tale         Hulu
# 5                   The Handmaid's Tale         Hulu
# 6                   The Handmaid's Tale         Hulu
# 7                   The Handmaid's Tale         Hulu
# 8                           The Undoing          HBO
# 9                           The Undoing          HBO
#
#                                             producer  year  page  page_id
# 0                                                ABC  2021     0        1
# 1  A Netflix Original Series in association with ...  2021     0        2
# 2                          20th Television Animation  2021     0        3
# 3                                     FX Productions  2021     0        4
# 4  Hulu, MGM, Daniel Wilson Productions, The Litt...  2021     0        5
# 5  Hulu, MGM, Daniel Wilson Productions, The Litt...  2021     0        5
# 6  Hulu, MGM, Daniel Wilson Productions, The Litt...  2021     0        5
# 7  Hulu, MGM, Daniel Wilson Productions, The Litt...  2021     0        5
# 8  HBO in association with Made Up Stories, Bloss...  2021     0        6
# 9  HBO in association with Made Up Stories, Bloss...  2021     0        6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29678 entries, 0 to 29677
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category     29678 non-null  object
#  1   logo         29678 non-null  object
#  2   production   26825 non-null  object
#  3   type         29678 non-null  object
#  4   title        29678 non-null  object
#  5   distributor  29675 non-null  object
#  6   producer     29678 non-null  object
#  7   year         29678 non-null  int64
#  8   page         29678 non-null  int64
#  9   page_id      29678 non-null  int64
# dtypes: int64(3), object(7)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()
# Out:
# category          0
# logo              0
# production     2853
# type              0
# title             0
# distributor       3
# producer          0
# year              0
# page              0
# page_id           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["production_code"] = df["production"].fillna("Unknown")
df["distributor"] = df["distributor"].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# category              0
# logo                  0
# production         2853
# type                  0
# title                 0
# distributor           0
# producer              0
# year                  0
# page                  0
# page_id               0
# production_code       0
# dtype: int64

# %%
df["production"] = df["production"].fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# category              0
# logo                  0
# production         2853
# type                  0
# title                 0
# distributor           0
# producer              0
# year                  0
# page                  0
# page_id               0
# production_code       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['category', 'logo', 'production', 'type', 'title', 'distributor',
#        'producer', 'year', 'page', 'page_id', 'production_code'],
#       dtype='object')

# %%
df = df.drop(columns=["production_code"])

# %%
df.columns
# Out:
# Index(['category', 'logo', 'production', 'type', 'title', 'distributor',
#        'producer', 'year', 'page', 'page_id'],
#       dtype='object')

# %%
df["type"].value_counts()
# Out:
# type
# Nominee    23739
# Winner      5939
# Name: count, dtype: int64

# %%
df["distributor"].value_counts().head(10)
# Out:
# distributor
# HBO               4442
# NBC               3623
# CBS               2963
# ABC               2945
# Netflix           2144
# FOX               1617
# FX Networks       1098
# Comedy Central     877
# PBS                778
# Showtime           743
# Name: count, dtype: int64

# %%
df["year"].min(), df["year"].max()
# Out:
# (1957, 2021)

# %%
df["year"].value_counts().sort_index()
# Out:
# year
# 1957      20
# 1958      40
# 1959      20
# 1961      10
# 1962      10
#         ...
# 2017    2413
# 2018    2562
# 2019    2613
# 2020    2478
# 2021    2506
# Name: count, Length: 61, dtype: int64

# %%
df["category"].nunique()
# Out:
# 1821

# %%
df["category"].value_counts().head(10)
# Out:
# category
# Outstanding Technical Direction, Camerawork, Video For A Miniseries, Movie Or A Special - 2007            117
# Outstanding Technical Direction, Camerawork, Video For A Miniseries, Movie Or A Special - 2008            111
# Outstanding Drama Series - 2021                                                                           109
# Outstanding Animated Program - 2019                                                                       102
# Outstanding Technical Direction, Camerawork, Video Control For A Miniseries, Movie Or A Special - 2013    101
# Outstanding Writing For A Variety Series - 2019                                                           101
# Outstanding Technical Direction, Camerawork, Video Control For A Miniseries, Movie Or A Special - 2009    100
# Outstanding Technical Direction, Camerawork, Video Control For A Miniseries, Movie Or A Special - 2011    100
# Outstanding Comedy Series - 2021                                                                           99
# Outstanding Technical Direction, Camerawork, Video Control For A Miniseries, Movie Or A Special - 2010     98
# Name: count, dtype: int64

# %%
df["category"].iloc[0]
# Out:
# 'Outstanding Character Voice-Over Performance - 2021'

# %%
df["title"].nunique()
# Out:
# 2022

# %%
df["title"].value_counts().head(10)
# Out:
# title
# Saturday Night Live                859
# The Voice                          582
# Dancing With The Stars             538
# Game Of Thrones                    466
# The Amazing Race                   425
# The Oscars                         416
# American Idol                      276
# Top Chef                           265
# Project Runway                     256
# The Daily Show With Jon Stewart    247
# Name: count, dtype: int64

# %%
df[df["type"] == "Winner"]["distributor"].value_counts().head(10)
# Out:
# distributor
# HBO                1317
# NBC                 690
# CBS                 444
# ABC                 443
# Netflix             393
# FOX                 309
# Comedy Central      253
# FX Networks         225
# PBS                 172
# Cartoon Network     125
# Name: count, dtype: int64

# %%
df["distributor"].nunique()
# Out:
# 200

# %%
df[df["distributor"] == "Netflix"]["year"].min()
# Out:
# 2013

# %%
df["year"].nunique()
# Out:
# 61

# %%
df["year"].unique()
# Out:
# array([2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011,
#        2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003, 2002, 2001, 2000,
#        1999, 1998, 1997, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989,
#        1988, 1987, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978,
#        1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 1969, 1968, 1967,
#        1966, 1962, 1961, 1959, 1958, 1957])

# %%
df["distributor"].value_counts(normalize=True).head(10)
# Out:
# distributor
# HBO               0.149673
# NBC               0.122077
# CBS               0.099838
# ABC               0.099232
# Netflix           0.072242
# FOX               0.054485
# FX Networks       0.036997
# Comedy Central    0.029551
# PBS               0.026215
# Showtime          0.025035
# Name: proportion, dtype: float64

# %%
winners_by_year = df[df["type"] == "Winner"]["year"].value_counts().sort_index()
winners_by_year
# Out:
# year
# 1957      4
# 1958      8
# 1959      4
# 1961      3
# 1962      2
#        ...
# 2017    494
# 2018    436
# 2019    461
# 2020    479
# 2021    460
# Name: count, Length: 61, dtype: int64

# %%
df.describe(include="all")
# Out:
#                                                  category  \
# count                                               29678
# unique                                               1821
# top     Outstanding Technical Direction, Camerawork, V...
# freq                                                  117
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      logo  \
# count                                               29678
# unique                                               1803
# top     /sites/all/themes/emmys/img/winners_outsanding...
# freq                                                 5555
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                 production     type                title  \
# count                                26825    29678                29678
# unique                               16460        2                 2022
# top     Lorne Michaels, Executive Producer  Nominee  Saturday Night Live
# freq                                    35    23739                  859
# mean                                   NaN      NaN                  NaN
# std                                    NaN      NaN                  NaN
# min                                    NaN      NaN                  NaN
# 25%                                    NaN      NaN                  NaN
# 50%                                    NaN      NaN                  NaN
# 75%                                    NaN      NaN                  NaN
# max                                    NaN      NaN                  NaN
#
#        distributor                                           producer  \
# count        29678                                              29678
# unique         200                                               1507
# top            HBO  SNL Studios in association with Universal Tele...
# freq          4442                                                929
# mean           NaN                                                NaN
# std            NaN                                                NaN
# min            NaN                                                NaN
# 25%            NaN                                                NaN
# 50%            NaN                                                NaN
# 75%            NaN                                                NaN
# max            NaN                                                NaN
#
#                 year          page       page_id
# count   29678.000000  29678.000000  29678.000000
# unique           NaN           NaN           NaN
# top              NaN           NaN           NaN
# freq             NaN           NaN           NaN
# mean     2013.611025    466.123425      5.497035
# std         7.760282    361.741625      2.877462
# min      1957.000000      0.000000      1.000000
# 25%      2010.000000    188.000000      3.000000
# 50%      2015.000000    391.000000      5.000000
# 75%      2019.000000    685.000000      8.000000
# max      2021.000000   2281.000000     10.000000

# %%
df = df.drop(columns=["logo", "page", "page_id"])

# %%
df.columns
# Out:
# Index(['category', 'production', 'type', 'title', 'distributor', 'producer',
#        'year'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29678 entries, 0 to 29677
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category     29678 non-null  object
#  1   production   26825 non-null  object
#  2   type         29678 non-null  object
#  3   title        29678 non-null  object
#  4   distributor  29678 non-null  object
#  5   producer     29678 non-null  object
#  6   year         29678 non-null  int64
# dtypes: int64(1), object(6)
# memory usage: 1.6+ MB

# %%
winners = df[df["type"] == "Winner"]

# %%
df["type"].value_counts()
# Out:
# type
# Nominee    23739
# Winner      5939
# Name: count, dtype: int64

# %%
winners = df[df["type"] == "Winner"]

# %%
winners.shape
# Out:
# (5939, 7)

# %%
top_distrubutors = winners["distributor"].value_counts().head(10)
top_distrubutors
# Out:
# distributor
# HBO                1317
# NBC                 690
# CBS                 444
# ABC                 443
# Netflix             393
# FOX                 309
# Comedy Central      253
# FX Networks         225
# PBS                 172
# Cartoon Network     125
# Name: count, dtype: int64

# %%
winners = df[df["type"] == "Winner"]

# %%
top_distributors = winners["distributor"].value_counts().head(10)

# %%
top_distributors
# Out:
# distributor
# HBO                1317
# NBC                 690
# CBS                 444
# ABC                 443
# Netflix             393
# FOX                 309
# Comedy Central      253
# FX Networks         225
# PBS                 172
# Cartoon Network     125
# Name: count, dtype: int64

# %%
top_distributors.plot(kind="bar", figsize=(10, 5))

plt.title("Top Distributors for Emmy Winners")
plt.xlabel("Distributor")
plt.ylabel("Number of Wins")
plt.xticks(rotation=45)
plt.show()

# %%
winners_by_year = winners["year"].value_counts().sort_index()

plt.figure(figsize=(10,5))

winners_by_year.plot(kind="line")

plt.title("Emmy Winners Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Wins")

plt.show()

# %%
import matplotlib.pyplot as plt

wins_by_year = winners.groupby("year").size()

plt.figure(figsize=(10, 5))

plt.scatter(wins_by_year.index, wins_by_year.values)

plt.title("Emmy Wins Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Wins")

plt.show()
